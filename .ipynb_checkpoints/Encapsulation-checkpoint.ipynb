# %%
# lists of  nested lists
list1 = [1,2,3,4,5,6]
# nested list (list of list)
list2=[[1,2,3],[4,5,6],[7,8,9]]
list2[2][0]
# Out:
# 7

# %%
list2
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
# tuple 
# tuples are immutable datatypes(unchangeable)
tupll = ("parul",22,"bharat",45.5,"vadodara",99)
tupll
# Out:
# ('parul', 22, 'bharat', 45.5, 'vadodara', 99)

# %%
tupll.count("parul")
# Out:
# 1

# %%
tupll[2]
# Out:
# 'bharat'

# %%
# dictionary data types

# %%
dict1 ={"Name":"Sumit","Age":10,"Mob-no":323}
type(dict1)
# Out:
# dict

# %%
# formkey methods
keys =["name","Age","Mob-no"]
values =["sumit",10,123]
dict2=dict.fromkeys(keys,0)
dict2
# Out:
# {'name': 0, 'Age': 0, 'Mob-no': 0}

# %%
keys =["A","B","c"]
values = ["sumit",20,123]
dict3=dict.fromkeys(keys,20)
dict3
# Out:
# {'A': 20, 'B': 20, 'c': 20}

# %%
# key()
dict3={"Name":"Sumit","Age":10,"Mob-no":324}
dict3.keys()
# Out:
# dict_keys(['Name', 'Age', 'Mob-no'])

# %%
# values
dict3.values()
# Out:
# dict_values(['Sumit', 10, 324])

# %%
# GET
print(dict3.get("mob-no"))
# Out:
# None

# %%
# items()
dict3.items()
# Out:
# dict_items([('Name', 'Sumit'), ('Age', 10), ('Mob-no', 324)])

# %%
#pop(): remove item form the dict using key name
dict4={"car": "Thar","Model":2026,"color":"black"}
# synatax : dict.pop("key")
dict4.pop("Model")
dict4
# Out:
# {'car': 'Thar', 'color': 'black'}

# %%
# popitem()
dict4={"car": "Thar","Model":2026,"color":"black"}
dict4.popitem()
dict4a
# Out:
# {'car': 'Thar', 'Model': 2026}

# %%
# update()
dict4={"car": "Thar","Model":2026,"color":"black"}
dict4.update({"engine_size":"20litr"})
dict4
# Out:
# {'car': 'Thar', 'Model': 2026, 'color': 'black', 'engine_size': '20litr'}

# %%
dict4={"car": "Thar","Model":2026,"color":"black"}
dict4["engine_size"]="20litr"
dict4
# Out:
# {'car': 'Thar', 'Model': 2026, 'color': 'black', 'engine_size': '20litr'}
