# %%
#1. (Easy) Take a string from user and replace all spaces with underscore _ using
#replace() method.
text=input()
text = "sumit"
text.replace("sumit","sumit_23")
text
# Out:
#  s
# 'sumit'

# %%
#2. (Easy) Take any string and remove leading and trailing spaces using strip().
text = "sumit"
text.rstrip()
text
# Out:
# 'sumit'
