# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\ntt\\Downloads\\Data_Train.xlsx - Sheet1.csv")
df
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# 2      DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# 3            CCU → NAG → BLR    18:05         23:30   5h 25m      1 stop
# 4            BLR → NAG → DEL    16:50         21:35   4h 45m      1 stop
# ...                      ...      ...           ...      ...         ...
# 10678              CCU → BLR    19:55         22:25   2h 30m    non-stop
# 10679              CCU → BLR    20:45         23:20   2h 35m    non-stop
# 10680              BLR → DEL    08:20         11:20       3h    non-stop
# 10681              BLR → DEL    11:30         14:10   2h 40m    non-stop
# 10682  DEL → GOI → BOM → COK    10:55         19:15   8h 20m     2 stops
#
#       Additional_Info  Price
# 0             No info   3897
# 1             No info   7662
# 2             No info  13882
# 3             No info   6218
# 4             No info  13302
# ...               ...    ...
# 10678         No info   4107
# 10679         No info   4145
# 10680         No info   7229
# 10681         No info  12648
# 10682         No info  11753
#
# [10683 rows x 11 columns]

# %%
# 1. Load the Flight Price dataset into a Pandas DataFrame and display the first
# five rows.
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
# 2. Find the number of rows and columns in the dataset.
df.shape
# Out:
# (10683, 11)

# %%
# 3. Display all column names in the dataset.
df.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price'],
#       dtype='object')

# %%
# 4. Display the data types of all columns.
df.dtypes
# Out:
# Airline            object
# Date_of_Journey    object
# Source             object
# Destination        object
# Route              object
# Dep_Time           object
# Arrival_Time       object
# Duration           object
# Total_Stops        object
# Additional_Info    object
# Price               int64
# dtype: object

# %%
# 5. Use df.info() to inspect the structure of the dataset.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %%
# 6. Check the number of missing values in each column.
df.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
# 7. Check the percentage of missing values in each column.
df.isna().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
# 8. Display the unique values and frequency of each value in the Airline column.
df["Airline"].value_counts()
# Out:
# Airline
# Jet Airways                          3849
# IndiGo                               2053
# Air India                            1752
# Multiple carriers                    1196
# SpiceJet                              818
# Vistara                               479
# Air Asia                              319
# GoAir                                 194
# Multiple carriers Premium economy      13
# Jet Airways Business                    6
# Vistara Premium economy                 3
# Trujet                                  1
# Name: count, dtype: int64

# %%
# 9.Display the frequency distribution of Total_Stops, including missing values.
df["Total_Stops"].value_counts(dropna = False)
# Out:
# Total_Stops
# 1 stop      5625
# non-stop    3491
# 2 stops     1520
# 3 stops       45
# NaN            1
# 4 stops        1
# Name: count, dtype: int64

# %%
# 10.Convert Date_of_Journey into a datetime format.

df["Date_of_Journey"]= pd.to_datetime(df["Date_of_Journey"],dayfirst=False)

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-05-01   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-06-09     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      2019-05-12   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      2019-03-01  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
# 11.Extract the day from Date_of_Journey and create a day column.
df = pd.DataFrame({'Date_of_Journey': ['2024-01-15', '20-02-2023', '2024-03-25']})
df
# Out:
#   Date_of_Journey
# 0      2024-01-15
# 1      20-02-2023
# 2      2024-03-25

# %%
#12.Extract the month from Date_of_Journey and create a month column.
# Convert Date_of_Journey to datetime

# Display result
df["Date_of_Journey"]=pd.to_datetime(df["Date_of_Journey"]).dt.month
df["Date_of_Journey"]
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 10678    1
# 10679    1
# 10680    1
# 10681    1
# 10682    1
# Name: Date_of_Journey, Length: 10683, dtype: int32

# %%
#13.Extract the year from Date_of_Journey and create a year column.

df["Date_of_Journey"]=pd.to_datetime(df["Date_of_Journey"]).dt.year
df["Date_of_Journey"]
# Out:
# 0        1970
# 1        1970
# 2        1970
# 3        1970
# 4        1970
#          ...
# 10678    1970
# 10679    1970
# 10680    1970
# 10681    1970
# 10682    1970
# Name: Date_of_Journey, Length: 10683, dtype: int32

# %%
# 14.Drop the original Date_of_Journey column after extracting the required
# # features.
df1.drop(df1["Date_of_Journey"],axis = 1,inplace = True)
df1
# Out:
#            Airline    Source Destination                  Route Dep_Time  \
# 0           IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1        Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2      Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3           IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4           IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
# ...            ...       ...         ...                    ...      ...
# 10678     Air Asia   Kolkata    Banglore              CCU → BLR    19:55
# 10679    Air India   Kolkata    Banglore              CCU → BLR    20:45
# 10680  Jet Airways  Banglore       Delhi              BLR → DEL    08:20
# 10681      Vistara  Banglore   New Delhi              BLR → DEL    11:30
# 10682    Air India     Delhi      Cochin  DEL → GOI → BOM → COK    10:55
#
#        Arrival_Time Duration Total_Stops Additional_Info  Price
# 0      01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1             13:15   7h 25m     2 stops         No info   7662
# 2      04:25 10 Jun      19h     2 stops         No info  13882
# 3             23:30   5h 25m      1 stop         No info   6218
# 4             21:35   4h 45m      1 stop         No info  13302
# ...             ...      ...         ...             ...    ...
# 10678         22:25   2h 30m    non-stop         No info   4107
# 10679         23:20   2h 35m    non-stop         No info   4145
# 10680         11:20       3h    non-stop         No info   7229
# 10681         14:10   2h 40m    non-stop         No info  12648
# 10682         19:15   8h 20m     2 stops         No info  11753
#
# [10683 rows x 10 columns]

# %%
# 15.Convert Dep_Time into datetime format and extract the departure hour into
# Dep_Hour.
df['Dep_Time'] = pd.to_datetime(df['Dep_Time'], format='%H:%M', errors='coerce')
df['Dep_Hour'] = df['Dep_Time'].dt.hour
df
# Out:
#            Airline  Date_of_Journey    Source Destination  \
# 0           IndiGo                1  Banglore   New Delhi
# 1        Air India                1   Kolkata    Banglore
# 2      Jet Airways                1     Delhi      Cochin
# 3           IndiGo                1   Kolkata    Banglore
# 4           IndiGo                1  Banglore   New Delhi
# ...            ...              ...       ...         ...
# 10678     Air Asia                1   Kolkata    Banglore
# 10679    Air India                1   Kolkata    Banglore
# 10680  Jet Airways                1  Banglore       Delhi
# 10681      Vistara                1  Banglore   New Delhi
# 10682    Air India                1     Delhi      Cochin
#
#                        Route            Dep_Time  Arrival_Time Duration  \
# 0                  BLR → DEL 1900-01-01 22:20:00  01:10 22 Mar   2h 50m
# 1      CCU → IXR → BBI → BLR 1900-01-01 05:50:00         13:15   7h 25m
# 2      DEL → LKO → BOM → COK 1900-01-01 09:25:00  04:25 10 Jun      19h
# 3            CCU → NAG → BLR 1900-01-01 18:05:00         23:30   5h 25m
# 4            BLR → NAG → DEL 1900-01-01 16:50:00         21:35   4h 45m
# ...                      ...                 ...           ...      ...
# 10678              CCU → BLR 1900-01-01 19:55:00         22:25   2h 30m
# 10679              CCU → BLR 1900-01-01 20:45:00         23:20   2h 35m
# 10680              BLR → DEL 1900-01-01 08:20:00         11:20       3h
# 10681              BLR → DEL 1900-01-01 11:30:00         14:10   2h 40m
# 10682  DEL → GOI → BOM → COK 1900-01-01 10:55:00         19:15   8h 20m
#
#       Total_Stops Additional_Info  Price  Dep_Hour
# 0        non-stop         No info   3897        22
# 1         2 stops         No info   7662         5
# 2         2 stops         No info  13882         9
# 3          1 stop         No info   6218        18
# 4          1 stop         No info  13302        16
# ...           ...             ...    ...       ...
# 10678    non-stop         No info   4107        19
# 10679    non-stop         No info   4145        20
# 10680    non-stop         No info   7229         8
# 10681    non-stop         No info  12648        11
# 10682     2 stops         No info  11753        10
#
# [10683 rows x 12 columns]

# %%
# 16.Extract the departure minute from Dep_Time and create Dep_Minute.
flights <- flights %>%
  mutate(
    Dep_Minute = Dep_Time %% 100  # remainder after dividing by 100
  )

print(flights)
# Out:
#   Cell In[22], line 2
#     flights <- flights %>%
#                         ^
# SyntaxError: invalid syntax
